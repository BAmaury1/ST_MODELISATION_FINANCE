# %%
import matplotlib.pyplot as plt
import numpy as np

n=1000 #
sigma=np.arange(1,201) #liste des différents écart types
tau=1000 #nombre de lignes de VA 

'''
taille = (2,5,len([1,2,3]))
test=np.random.normal(0,[1,2,3],size=taille)
print(test)

print(test.sum(axis=1))

'''

epsilon=np.random.normal(0,sigma,size=(n,tau,len(sigma))) #tableau de VA avec chaque colonne correspond à un écart type du tableau sigma, sur tau ligne et on repete le truc n fois



X_tau=epsilon.sum(axis=1) #on somme toute les VA d'une colonne pour chaqu'une des n répétitions
print(X_tau)
X_std=np.std(X_tau, axis=0)  #trace les différents écart type

plt.plot(X_std)
marche_aleat=epsilon.cumsum(axis=1) #on somme pour avoir la marche aléatoire

#plt.plot(marche_aleat[0,:,12]) #[moyenne]

#plt.plot(X_std)
plt.show()
# Out:
# [[-3.77942301e+01  5.29782935e+01  5.46193299e+01 ...  6.97050277e+01
#   -4.92506644e+03  8.16309171e+03]
#  [-7.62930496e+01  9.17087023e+00  1.39494902e+02 ...  1.33497976e+03
#   -9.90674177e+03 -3.43294922e+03]
#  [-7.71544542e+01 -1.53865742e+01  1.52232523e+01 ...  1.08814955e+04
#    2.96043783e+03 -2.88424319e+03]
#  ...
#  [-2.11213487e+01  8.72558664e+01 -2.30780957e+02 ...  5.69781147e+03
#    7.47531751e+02  6.68440083e+02]
#  [ 3.70038476e+00  4.14822501e+01  1.13348796e+02 ...  2.64508843e+01
#   -7.66746482e+03 -3.57596150e+03]
#  [ 2.53085411e+01  3.14271609e+01  1.06430682e+02 ... -5.51643771e+03
#   -9.41544530e+03 -2.58517959e+03]]
